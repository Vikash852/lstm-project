# %% [markdown]
# <a href="https://colab.research.google.com/github/Vikash852/lstm-project/blob/main/lstm_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
faqs = """About the Program
What is the course fee for  Data Science Mentorship Program (DSMP 2023)
The course follows a monthly subscription model where you have to make monthly payments of Rs 799/month.
What is the total duration of the course?
The total duration of the course is 7 months. So the total course fee becomes 799*7 = Rs 5600(approx.)
What is the syllabus of the mentorship program?
We will be covering the following modules:
Python Fundamentals
Python libraries for Data Science
Data Analysis
SQL for Data Science
Maths for Machine Learning
ML Algorithms
Practical ML
MLOPs
Case studies

Will Deep Learning and NLP be a part of this program?
No, NLP and Deep Learning both are not a part of this program’s curriculum.
What if I miss a live session? Will I get a recording of the session?
Yes all our sessions are recorded, so even if you miss a session you can go back and watch the recording.
Where can I find the class schedule?

Roughly, all the sessions last 2 hours.
What is the language spoken by the instructor during the sessions?
Hinglish
How will I be informed about the upcoming class?
You will get a mail from our side before every paid session once you become a paid user.
Can I do this course if I am from a non-tech background?
Yes, absolutely.
I am late, can I join the program in the middle?
Absolutely, you can join the program anytime.
If I join/pay in the middle, will I be able to see all the past lectures?
Yes, once you make the payment you will be able to see all the past content in your dashboard.
Where do I have to submit the task?
You don’t have to submit the task. We will provide you with the solutions, you have to self evaluate the task yourself.
Will we do case studies in the program?
Yes.
Where can we contact you?
You can mail
Payment/Registration related questions
Where do we have to make our payments? Your YouTube channel or website?
You have to make all your monthly payments on our website. Here is the link for our
Can we pay the entire amount of Rs 5600 all at once?
Unfortunately no, the program follows a monthly subscription model.
What is the validity of monthly subscription? Suppose if I pay on 15th Jan, then do I have to pay again on 1st Feb or 15th Feb
15th Feb. The validity period is 30 days from the day you make the payment. So essentially you can join anytime you don’t have to wait for a month to end.
What if I don’t like the course after making the payment. What is the refund policy?
You get a 7 days refund period from the day you have made the payment.
I am living outside India and I am not able to make the payment on the website, what should I do?
You have to contact us by sending a mail
Post registration queries
Till when can I view the paid videos on the website?
This one is tricky, so read carefully. You can watch the videos till your subscription is valid. Suppose you have purchased subscription on 21st Jan, you will be able to watch all the past paid sessions in the period of 21st Jan to 20th Feb. But after 21st Feb you will have to purchase the subscription again.
But once the course is over and you have paid us Rs 5600(or 7 installments of Rs 799) you will be able to watch the paid sessions till Aug 2024.
Why lifetime validity is not provided?
Because of the low course fee.
Where can I reach out in case of a doubt after the session?
You will have to fill a google form provided in your dashboard and our team will contact you for a 1 on 1 doubt clearance session
If I join the program late, can I still ask past week doubts?
Yes, just select past week doubt in the doubt clearance google form.
I am living outside India and I am not able to make the payment on the website, what should I do?
You have to contact us by sending a mail
Certificate and Placement Assistance related queries
What is the criteria to get the certificate?
There are 2 criterias:
You have to pay the entire fee of Rs 5600
You have to attempt all the course assessments.
I am joining late. How can I pay payment of the earlier months?
You will get a link to pay fee of earlier months in your dashboard once you pay for the current month.
I have read that Placement assistance is a part of this program. What comes under Placement assistance?
This is to clarify that Placement assistance does not mean Placement guarantee. So we dont guarantee you any jobs or for that matter even interview calls. So if you are planning to join this course just for placements, I am afraid you will be disappointed. Here is what comes under placement assistance
Portfolio Building sessions
Soft skill sessions
Sessions with industry mentors
Discussion on Job hunting strategies
"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([faqs])

# %%
len(tokenizer.word_index)
# Out:
# 259

# %%
input_sequences = []
for sentence in faqs.split('\n'):
  tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]

  for i in range(1,len(tokenized_sentence)):
    input_sequences.append(tokenized_sentence[:i+1])

# %%
input_sequences
# Out:
# [[83, 1],
#  [83, 1, 13],
#  [11, 7],
#  [11, 7, 1],
#  [11, 7, 1, 12],
#  [11, 7, 1, 12, 40],
#  [11, 7, 1, 12, 40, 14],
#  [11, 7, 1, 12, 40, 14, 50],
#  [11, 7, 1, 12, 40, 14, 50, 60],
#  [11, 7, 1, 12, 40, 14, 50, 60, 84],
#  [11, 7, 1, 12, 40, 14, 50, 60, 84, 13],
#  [11, 7, 1, 12, 40, 14, 50, 60, 84, 13, 137],
#  [11, 7, 1, 12, 40, 14, 50, 60, 84, 13, 137, 138],
#  [1, 12],
#  [1, 12, 85],
#  [1, 12, 85, 5],
#  [1, 12, 85, 5, 41],
#  [1, 12, 85, 5, 41, 29],
#  [1, 12, 85, 5, 41, 29, 86],
#  [1, 12, 85, 5, 41, 29, 86, 30],
#  [1, 12, 85, 5, 41, 29, 86, 30, 2],
#  [1, 12, 85, 5, 41, 29, 86, 30, 2, 6],
#  [1, 12, 85, 5, 41, 29, 86, 30, 2, 6, 4],
#  [1, 12, 85, 5, 41, 29, 86, 30, 2, 6, 4, 25],
#  [1, 12, 85, 5, 41, 29, 86, 30, 2, 6, 4, 25, 41],
#  [1, 12, 85, 5, 41, 29, 86, 30, 2, 6, 4, 25, 41, 61],
#  [1, 12, 85, 5, 41, 29, 86, 30, 2, 6, 4, 25, 41, 61, 8],
#  [1, 12, 85, 5, 41, 29, 86, 30, 2, 6, 4, 25, 41, 61, 8, 31],
#  [1, 12, 85, 5, 41, 29, 86, 30, 2, 6, 4, 25, 41, 61, 8, 31, 62],
#  [1, 12, 85, 5, 41, 29, 86, 30, 2, 6, 4, 25, 41, 61, 8, 31, 62, 63],
#  [11, 7],
#  [11, 7, 1],
#  [11, 7, 1, 64],
#  [11, 7, 1, 64, 87],
#  [11, 7, 1, 64, 87, 8],
#  [11, 7, 1, 64, 87, 8, 1],
#  [11, 7, 1, 64, 87, 8, 1, 12],
#  [1, 64],
#  [1, 64, 87],
#  [1, 64, 87, 8],
#  [1, 64, 87, 8, 1],
#  [1, 64, 87, 8, 1, 12],
#  [1, 64, 87, 8, 1, 12, 7],
#  [1, 64, 87, 8, 1, 12, 7, 51],
#  [1, 64, 87, 8, 1, 12, 7, 51, 65],
#  [1, 64, 87, 8, 1, 12, 7, 51, 65, 32],
#  [1, 64, 87, 8, 1, 12, 7, 51, 65, 32, 1],
#  [1, 64, 87, 8, 1, 12, 7, 51, 65, 32, 1, 64],
#  [1, 64, 87, 8, 1, 12, 7, 51, 65, 32, 1, 64, 12],
#  [1, 64, 87, 8, 1, 12, 7, 51, 65, 32, 1, 64, 12, 40],
#  [1, 64, 87, 8, 1, 12, 7, 51, 65, 32, 1, 64, 12, 40, 139],
#  [1, 64, 87, 8, 1, 12, 7, 51, 65, 32, 1, 64, 12, 40, 139, 62],
#  [1, 64, 87, 8, 1, 12, 7, 51, 65, 32, 1, 64, 12, 40, 139, 62, 51],
#  [1, 64, 87, 8, 1, 12, 7, 51, 65, 32, 1, 64, 12, 40, 139, 62, 51, 31],
#  [1, 64, 87, 8, 1, 12, 7, 51, 65, 32, 1, 64, 12, 40, 139, 62, 51, 31, 52],
#  [1, 64, 87, 8, 1, 12, 7, 51, 65, 32, 1, 64, 12, 40, 139, 62, 51, 31, 52, 140],
#  [11, 7],
#  [11, 7, 1],
#  [11, 7, 1, 141],
#  [11, 7, 1, 141, 8],
#  [11, 7, 1, 141, 8, 1],
#  [11, 7, 1, 141, 8, 1, 84],
#  [11, 7, 1, 141, 8, 1, 84, 13],
#  [26, 9],
#  [26, 9, 17],
#  [26, 9, 17, 142],
#  [26, 9, 17, 142, 1],
#  [26, 9, 17, 142, 1, 143],
#  [26, 9, 17, 142, 1, 143, 144],
#  [88, 145],
#  [88, 146],
#  [88, 146, 14],
#  [88, 146, 14, 50],
#  [88, 146, 14, 50, 60],
#  [50, 147],
#  [148, 14],
#  [148, 14, 50],
#  [148, 14, 50, 60],
#  [149, 14],
#  [149, 14, 150],
#  [149, 14, 150, 66],
#  [89, 151],
#  [152, 89],
#  [67, 90],
#  [9, 91],
#  [9, 91, 66],
#  [9, 91, 66, 18],
#  [9, 91, 66, 18, 92],
#  [9, 91, 66, 18, 92, 17],
#  [9, 91, 66, 18, 92, 17, 5],
#  [9, 91, 66, 18, 92, 17, 5, 68],
#  [9, 91, 66, 18, 92, 17, 5, 68, 8],
#  [9, 91, 66, 18, 92, 17, 5, 68, 8, 27],
#  [9, 91, 66, 18, 92, 17, 5, 68, 8, 27, 13],
#  [93, 92],
#  [93, 92, 18],
#  [93, 92, 18, 91],
#  [93, 92, 18, 91, 66],
#  [93, 92, 18, 91, 66, 154],
#  [93, 92, 18, 91, 66, 154, 53],
#  [93, 92, 18, 91, 66, 154, 53, 42],
#  [93, 92, 18, 91, 66, 154, 53, 42, 5],
#  [93, 92, 18, 91, 66, 154, 53, 42, 5, 68],
#  [93, 92, 18, 91, 66, 154, 53, 42, 5, 68, 8],
#  [93, 92, 18, 91, 66, 154, 53, 42, 5, 68, 8, 27],
#  [93, 92, 18, 91, 66, 154, 53, 42, 5, 68, 8, 27, 155],
#  [93, 92, 18, 91, 66, 154, 53, 42, 5, 68, 8, 27, 155, 156],
#  [11, 19],
#  [11, 19, 3],
#  [11, 19, 3, 94],
#  [11, 19, 3, 94, 5],
#  [11, 19, 3, 94, 5, 157],
#  [11, 19, 3, 94, 5, 157, 33],
#  [11, 19, 3, 94, 5, 157, 33, 9],
#  [11, 19, 3, 94, 5, 157, 33, 9, 3],
#  [11, 19, 3, 94, 5, 157, 33, 9, 3, 43],
#  [11, 19, 3, 94, 5, 157, 33, 9, 3, 43, 5],
#  [11, 19, 3, 94, 5, 157, 33, 9, 3, 43, 5, 95],
#  [11, 19, 3, 94, 5, 157, 33, 9, 3, 43, 5, 95, 8],
#  [11, 19, 3, 94, 5, 157, 33, 9, 3, 43, 5, 95, 8, 1],
#  [11, 19, 3, 94, 5, 157, 33, 9, 3, 43, 5, 95, 8, 1, 33],
#  [44, 20],
#  [44, 20, 34],
#  [44, 20, 34, 21],
#  [44, 20, 34, 21, 53],
#  [44, 20, 34, 21, 53, 158],
#  [44, 20, 34, 21, 53, 158, 32],
#  [44, 20, 34, 21, 53, 158, 32, 96],
#  [44, 20, 34, 21, 53, 158, 32, 96, 19],
#  [44, 20, 34, 21, 53, 158, 32, 96, 19, 2],
#  [44, 20, 34, 21, 53, 158, 32, 96, 19, 2, 94],
#  [44, 20, 34, 21, 53, 158, 32, 96, 19, 2, 94, 5],
#  [44, 20, 34, 21, 53, 158, 32, 96, 19, 2, 94, 5, 33],
#  [44, 20, 34, 21, 53, 158, 32, 96, 19, 2, 94, 5, 33, 2],
#  [44, 20, 34, 21, 53, 158, 32, 96, 19, 2, 94, 5, 33, 2, 10],
#  [44, 20, 34, 21, 53, 158, 32, 96, 19, 2, 94, 5, 33, 2, 10, 159],
#  [44, 20, 34, 21, 53, 158, 32, 96, 19, 2, 94, 5, 33, 2, 10, 159, 160],
#  [44, 20, 34, 21, 53, 158, 32, 96, 19, 2, 94, 5, 33, 2, 10, 159, 160, 18],
#  [44, 20, 34, 21, 53, 158, 32, 96, 19, 2, 94, 5, 33, 2, 10, 159, 160, 18, 54],
#  [44,
#   20,
#   34,
#   21,
#   53,
#   158,
#   32,
#   96,
#   19,
#   2,
#   94,
#   5,
#   33,
#   2,
#   10,
#   159,
#   160,
#   18,
#   54,
#   1],
#  [44,
#   20,
#   34,
#   21,
#   53,
#   158,
#   32,
#   96,
#   19,
#   2,
#   94,
#   5,
#   33,
#   2,
#   10,
#   159,
#   160,
#   18,
#   54,
#   1,
#   95],
#  [30, 10],
#  [30, 10, 3],
#  [30, 10, 3, 161],
#  [30, 10, 3, 161, 1],
#  [30, 10, 3, 161, 1, 97],
#  [30, 10, 3, 161, 1, 97, 162],
#  [163, 20],
#  [163, 20, 1],
#  [163, 20, 1, 21],
#  [163, 20, 1, 21, 164],
#  [163, 20, 1, 21, 164, 98],
#  [163, 20, 1, 21, 164, 98, 165],
#  [11, 7],
#  [11, 7, 1],
#  [11, 7, 1, 166],
#  [11, 7, 1, 166, 167],
#  [11, 7, 1, 166, 167, 69],
#  [11, 7, 1, 166, 167, 69, 1],
#  [11, 7, 1, 166, 167, 69, 1, 168],
#  [11, 7, 1, 166, 167, 69, 1, 168, 169],
#  [11, 7, 1, 166, 167, 69, 1, 168, 169, 1],
#  [11, 7, 1, 166, 167, 69, 1, 168, 169, 1, 21],
#  [99, 9],
#  [99, 9, 3],
#  [99, 9, 3, 17],
#  [99, 9, 3, 17, 171],
#  [99, 9, 3, 17, 171, 83],
#  [99, 9, 3, 17, 171, 83, 1],
#  [99, 9, 3, 17, 171, 83, 1, 172],
#  [99, 9, 3, 17, 171, 83, 1, 172, 97],
#  [2, 9],
#  [2, 9, 43],
#  [2, 9, 43, 5],
#  [2, 9, 43, 5, 55],
#  [2, 9, 43, 5, 55, 56],
#  [2, 9, 43, 5, 55, 56, 34],
#  [2, 9, 43, 5, 55, 56, 34, 173],
#  [2, 9, 43, 5, 55, 56, 34, 173, 174],
#  [2, 9, 43, 5, 55, 56, 34, 173, 174, 175],
#  [2, 9, 43, 5, 55, 56, 34, 173, 174, 175, 35],
#  [2, 9, 43, 5, 55, 56, 34, 173, 174, 175, 35, 33],
#  [2, 9, 43, 5, 55, 56, 34, 173, 174, 175, 35, 33, 45],
#  [2, 9, 43, 5, 55, 56, 34, 173, 174, 175, 35, 33, 45, 2],
#  [2, 9, 43, 5, 55, 56, 34, 173, 174, 175, 35, 33, 45, 2, 176],
#  [2, 9, 43, 5, 55, 56, 34, 173, 174, 175, 35, 33, 45, 2, 176, 5],
#  [2, 9, 43, 5, 55, 56, 34, 173, 174, 175, 35, 33, 45, 2, 176, 5, 35],
#  [2, 9, 43, 5, 55, 56, 34, 173, 174, 175, 35, 33, 45, 2, 176, 5, 35, 177],
#  [10, 3],
#  [10, 3, 28],
#  [10, 3, 28, 27],
#  [10, 3, 28, 27, 12],
#  [10, 3, 28, 27, 12, 19],
#  [10, 3, 28, 27, 12, 19, 3],
#  [10, 3, 28, 27, 12, 19, 3, 22],
#  [10, 3, 28, 27, 12, 19, 3, 22, 56],
#  [10, 3, 28, 27, 12, 19, 3, 22, 56, 5],
#  [10, 3, 28, 27, 12, 19, 3, 22, 56, 5, 178],
#  [10, 3, 28, 27, 12, 19, 3, 22, 56, 5, 178, 179],
#  [10, 3, 28, 27, 12, 19, 3, 22, 56, 5, 178, 179, 180],
#  [44, 100],
#  [3, 22],
#  [3, 22, 70],
#  [3, 22, 70, 10],
#  [3, 22, 70, 10, 3],
#  [3, 22, 70, 10, 3, 36],
#  [3, 22, 70, 10, 3, 36, 1],
#  [3, 22, 70, 10, 3, 36, 1, 13],
#  [3, 22, 70, 10, 3, 36, 1, 13, 15],
#  [3, 22, 70, 10, 3, 36, 1, 13, 15, 1],
#  [3, 22, 70, 10, 3, 36, 1, 13, 15, 1, 101],
#  [100, 2],
#  [100, 2, 10],
#  [100, 2, 10, 36],
#  [100, 2, 10, 36, 1],
#  [100, 2, 10, 36, 1, 13],
#  [100, 2, 10, 36, 1, 13, 102],
#  [19, 3],
#  [19, 3, 36],
#  [19, 3, 36, 23],
#  [19, 3, 36, 23, 15],
#  [19, 3, 36, 23, 15, 1],
#  [19, 3, 36, 23, 15, 1, 101],
#  [19, 3, 36, 23, 15, 1, 101, 9],
#  [19, 3, 36, 23, 15, 1, 101, 9, 3],
#  [19, 3, 36, 23, 15, 1, 101, 9, 3, 17],
#  [19, 3, 36, 23, 15, 1, 101, 9, 3, 17, 37],
#  [19, 3, 36, 23, 15, 1, 101, 9, 3, 17, 37, 4],
#  [19, 3, 36, 23, 15, 1, 101, 9, 3, 17, 37, 4, 103],
#  [19, 3, 36, 23, 15, 1, 101, 9, 3, 17, 37, 4, 103, 20],
#  [19, 3, 36, 23, 15, 1, 101, 9, 3, 17, 37, 4, 103, 20, 1],
#  [19, 3, 36, 23, 15, 1, 101, 9, 3, 17, 37, 4, 103, 20, 1, 46],
#  [19, 3, 36, 23, 15, 1, 101, 9, 3, 17, 37, 4, 103, 20, 1, 46, 181],
#  [44, 45],
#  [44, 45, 2],
#  [44, 45, 2, 25],
#  [44, 45, 2, 25, 1],
#  [44, 45, 2, 25, 1, 24],
#  [44, 45, 2, 25, 1, 24, 2],
#  [44, 45, 2, 25, 1, 24, 2, 9],
#  [44, 45, 2, 25, 1, 24, 2, 9, 17],
#  [44, 45, 2, 25, 1, 24, 2, 9, 17, 37],
#  [44, 45, 2, 25, 1, 24, 2, 9, 17, 37, 4],
#  [44, 45, 2, 25, 1, 24, 2, 9, 17, 37, 4, 103],
#  [44, 45, 2, 25, 1, 24, 2, 9, 17, 37, 4, 103, 20],
#  [44, 45, 2, 25, 1, 24, 2, 9, 17, 37, 4, 103, 20, 1],
#  [44, 45, 2, 25, 1, 24, 2, 9, 17, 37, 4, 103, 20, 1, 46],
#  [44, 45, 2, 25, 1, 24, 2, 9, 17, 37, 4, 103, 20, 1, 46, 182],
#  [44, 45, 2, 25, 1, 24, 2, 9, 17, 37, 4, 103, 20, 1, 46, 182, 15],
#  [44, 45, 2, 25, 1, 24, 2, 9, 17, 37, 4, 103, 20, 1, 46, 182, 15, 38],
#  [44, 45, 2, 25, 1, 24, 2, 9, 17, 37, 4, 103, 20, 1, 46, 182, 15, 38, 71],
#  [30, 28],
#  [30, 28, 3],
#  [30, 28, 3, 6],
#  [30, 28, 3, 6, 4],
#  [30, 28, 3, 6, 4, 104],
#  [30, 28, 3, 6, 4, 104, 1],
#  [30, 28, 3, 6, 4, 104, 1, 72],
#  [2, 73],
#  [2, 73, 6],
#  [2, 73, 6, 4],
#  [2, 73, 6, 4, 104],
#  [2, 73, 6, 4, 104, 1],
#  [2, 73, 6, 4, 104, 1, 72],
#  [2, 73, 6, 4, 104, 1, 72, 26],
#  [2, 73, 6, 4, 104, 1, 72, 26, 9],
#  [2, 73, 6, 4, 104, 1, 72, 26, 9, 183],
#  [2, 73, 6, 4, 104, 1, 72, 26, 9, 183, 2],
#  [2, 73, 6, 4, 104, 1, 72, 26, 9, 183, 2, 105],
#  [2, 73, 6, 4, 104, 1, 72, 26, 9, 183, 2, 105, 1],
#  [2, 73, 6, 4, 104, 1, 72, 26, 9, 183, 2, 105, 1, 184],
#  [2, 73, 6, 4, 104, 1, 72, 26, 9, 183, 2, 105, 1, 184, 2],
#  [2, 73, 6, 4, 104, 1, 72, 26, 9, 183, 2, 105, 1, 184, 2, 6],
#  [2, 73, 6, 4, 104, 1, 72, 26, 9, 183, 2, 105, 1, 184, 2, 6, 4],
#  [2, 73, 6, 4, 104, 1, 72, 26, 9, 183, 2, 105, 1, 184, 2, 6, 4, 185],
#  [2, 73, 6, 4, 104, 1, 72, 26, 9, 183, 2, 105, 1, 184, 2, 6, 4, 185, 186],
#  [2, 73, 6, 4, 104, 1, 72, 26, 9, 183, 2, 105, 1, 184, 2, 6, 4, 185, 186, 1],
#  [2,
#   73,
#   6,
#   4,
#   104,
#   1,
#   72,
#   26,
#   9,
#   183,
#   2,
#   105,
#   1,
#   184,
#   2,
#   6,
#   4,
#   185,
#   186,
#   1,
#   72],
#  [2,
#   73,
#   6,
#   4,
#   104,
#   1,
#   72,
#   26,
#   9,
#   183,
#   2,
#   105,
#   1,
#   184,
#   2,
#   6,
#   4,
#   185,
#   186,
#   1,
#   72,
#   187],
#  [9, 26],
#  [9, 26, 28],
#  [9, 26, 28, 67],
#  [9, 26, 28, 67, 90],
#  [9, 26, 28, 67, 90, 15],
#  [9, 26, 28, 67, 90, 15, 1],
#  [9, 26, 28, 67, 90, 15, 1, 13],
#  [30, 10],
#  [30, 10, 26],
#  [30, 10, 26, 57],
#  [30, 10, 26, 57, 2],
#  [2, 10],
#  [2, 10, 55],
#  [24, 106],
#  [24, 106, 107],
#  [24, 106, 107, 188],
#  [30, 28],
#  [30, 28, 26],
#  [30, 28, 26, 6],
#  [30, 28, 26, 6, 4],
#  [30, 28, 26, 6, 4, 25],
#  [30, 28, 26, 6, 4, 25, 34],
#  [30, 28, 26, 6, 4, 25, 34, 61],
#  [30, 28, 26, 6, 4, 25, 34, 61, 38],
#  [30, 28, 26, 6, 4, 25, 34, 61, 38, 189],
#  [30, 28, 26, 6, 4, 25, 34, 61, 38, 189, 190],
#  [30, 28, 26, 6, 4, 25, 34, 61, 38, 189, 190, 58],
#  [30, 28, 26, 6, 4, 25, 34, 61, 38, 189, 190, 58, 47],
#  [2, 6],
#  [2, 6, 4],
#  [2, 6, 4, 25],
#  [2, 6, 4, 25, 20],
#  [2, 6, 4, 25, 20, 38],
#  [2, 6, 4, 25, 20, 38, 41],
#  [2, 6, 4, 25, 20, 38, 41, 61],
#  [2, 6, 4, 25, 20, 38, 41, 61, 16],
#  [2, 6, 4, 25, 20, 38, 41, 61, 16, 34],
#  [2, 6, 4, 25, 20, 38, 41, 61, 16, 34, 47],
#  [2, 6, 4, 25, 20, 38, 41, 61, 16, 34, 47, 108],
#  [2, 6, 4, 25, 20, 38, 41, 61, 16, 34, 47, 108, 7],
#  [2, 6, 4, 25, 20, 38, 41, 61, 16, 34, 47, 108, 7, 1],
#  [2, 6, 4, 25, 20, 38, 41, 61, 16, 34, 47, 108, 7, 1, 109],
#  [2, 6, 4, 25, 20, 38, 41, 61, 16, 34, 47, 108, 7, 1, 109, 14],
#  [2, 6, 4, 25, 20, 38, 41, 61, 16, 34, 47, 108, 7, 1, 109, 14, 34],
#  [10, 26],
#  [10, 26, 23],
#  [10, 26, 23, 1],
#  [10, 26, 23, 1, 110],
#  [10, 26, 23, 1, 110, 191],
#  [10, 26, 23, 1, 110, 191, 8],
#  [10, 26, 23, 1, 110, 191, 8, 31],
#  [10, 26, 23, 1, 110, 191, 8, 31, 52],
#  [10, 26, 23, 1, 110, 191, 8, 31, 52, 20],
#  [10, 26, 23, 1, 110, 191, 8, 31, 52, 20, 192],
#  [10, 26, 23, 1, 110, 191, 8, 31, 52, 20, 192, 45],
#  [193, 93],
#  [193, 93, 1],
#  [193, 93, 1, 13],
#  [193, 93, 1, 13, 85],
#  [193, 93, 1, 13, 85, 5],
#  [193, 93, 1, 13, 85, 5, 41],
#  [193, 93, 1, 13, 85, 5, 41, 29],
#  [193, 93, 1, 13, 85, 5, 41, 29, 86],
#  [11, 7],
#  [11, 7, 1],
#  [11, 7, 1, 74],
#  [11, 7, 1, 74, 8],
#  [11, 7, 1, 74, 8, 41],
#  [11, 7, 1, 74, 8, 41, 29],
#  [11, 7, 1, 74, 8, 41, 29, 111],
#  [11, 7, 1, 74, 8, 41, 29, 111, 19],
#  [11, 7, 1, 74, 8, 41, 29, 111, 19, 3],
#  [11, 7, 1, 74, 8, 41, 29, 111, 19, 3, 23],
#  [11, 7, 1, 74, 8, 41, 29, 111, 19, 3, 23, 16],
#  [11, 7, 1, 74, 8, 41, 29, 111, 19, 3, 23, 16, 75],
#  [11, 7, 1, 74, 8, 41, 29, 111, 19, 3, 23, 16, 75, 76],
#  [11, 7, 1, 74, 8, 41, 29, 111, 19, 3, 23, 16, 75, 76, 194],
#  [11, 7, 1, 74, 8, 41, 29, 111, 19, 3, 23, 16, 75, 76, 194, 28],
#  [11, 7, 1, 74, 8, 41, 29, 111, 19, 3, 23, 16, 75, 76, 194, 28, 3],
#  [11, 7, 1, 74, 8, 41, 29, 111, 19, 3, 23, 16, 75, 76, 194, 28, 3, 6],
#  [11, 7, 1, 74, 8, 41, 29, 111, 19, 3, 23, 16, 75, 76, 194, 28, 3, 6, 4],
#  [11, 7, 1, 74, 8, 41, 29, 111, 19, 3, 23, 16, 75, 76, 194, 28, 3, 6, 4, 23],
#  [11,
#   7,
#   1,
#   74,
#   8,
#   41,
#   29,
#   111,
#   19,
#   3,
#   23,
#   16,
#   75,
#   76,
#   194,
#   28,
#   3,
#   6,
#   4,
#   23,
#   112],
#  [11,
#   7,
#   1,
#   74,
#   8,
#   41,
#   29,
#   111,
#   19,
#   3,
#   23,
#   16,
#   75,
#   76,
#   194,
#   28,
#   3,
#   6,
#   4,
#   23,
#   112,
#   16],
#  [11,
#   7,
#   1,
#   74,
#   8,
#   41,
#   29,
#   111,
#   19,
#   3,
#   23,
#   16,
#   75,
#   76,
#   194,
#   28,
#   3,
#   6,
#   4,
#   23,
#   112,
#   16,
#   195],
#  [11,
#   7,
#   1,
#   74,
#   8,
#   41,
#   29,
#   111,
#   19,
#   3,
#   23,
#   16,
#   75,
#   76,
#   194,
#   28,
#   3,
#   6,
#   4,
#   23,
#   112,
#   16,
#   195,
#   48],
#  [11,
#   7,
#   1,
#   74,
#   8,
#   41,
#   29,
#   111,
#   19,
#   3,
#   23,
#   16,
#   75,
#   76,
#   194,
#   28,
#   3,
#   6,
#   4,
#   23,
#   112,
#   16,
#   195,
#   48,
#   58],
#  [11,
#   7,
#   1,
#   74,
#   8,
#   41,
#   29,
#   111,
#   19,
#   3,
#   23,
#   16,
#   75,
#   76,
#   194,
#   28,
#   3,
#   6,
#   4,
#   23,
#   112,
#   16,
#   195,
#   48,
#   58,
#   75],
#  [11,
#   7,
#   1,
#   74,
#   8,
#   41,
#   29,
#   111,
#   19,
#   3,
#   23,
#   16,
#   75,
#   76,
#   194,
#   28,
#   3,
#   6,
#   4,
#   23,
#   112,
#   16,
#   195,
#   48,
#   58,
#   75,
#   48],
#  [75, 48],
#  [75, 48, 1],
#  [75, 48, 1, 74],
#  [75, 48, 1, 74, 77],
#  [75, 48, 1, 74, 77, 7],
#  [75, 48, 1, 74, 77, 7, 196],
#  [75, 48, 1, 74, 77, 7, 196, 113],
#  [75, 48, 1, 74, 77, 7, 196, 113, 56],
#  [75, 48, 1, 74, 77, 7, 196, 113, 56, 1],
#  [75, 48, 1, 74, 77, 7, 196, 113, 56, 1, 114],
#  [75, 48, 1, 74, 77, 7, 196, 113, 56, 1, 114, 2],
#  [75, 48, 1, 74, 77, 7, 196, 113, 56, 1, 114, 2, 25],
#  [75, 48, 1, 74, 77, 7, 196, 113, 56, 1, 114, 2, 25, 1],
#  [75, 48, 1, 74, 77, 7, 196, 113, 56, 1, 114, 2, 25, 1, 24],
#  [75, 48, 1, 74, 77, 7, 196, 113, 56, 1, 114, 2, 25, 1, 24, 32],
#  [75, 48, 1, 74, 77, 7, 196, 113, 56, 1, 114, 2, 25, 1, 24, 32, 197],
#  [75, 48, 1, 74, 77, 7, 196, 113, 56, 1, 114, 2, 25, 1, 24, 32, 197, 2],
#  [75, 48, 1, 74, 77, 7, 196, 113, 56, 1, 114, 2, 25, 1, 24, 32, 197, 2, 10],
#  [75,
#   48,
#   1,
#   74,
#   77,
#   7,
#   196,
#   113,
#   56,
#   1,
#   114,
#   2,
#   25,
#   1,
#   24,
#   32,
#   197,
#   2,
#   10,
#   36],
#  [75,
#   48,
#   1,
#   74,
#   77,
#   7,
#   196,
#   113,
#   56,
#   1,
#   114,
#   2,
#   25,
#   1,
#   24,
#   32,
#   197,
#   2,
#   10,
#   36,
#   102],
#  [75,
#   48,
#   1,
#   74,
#   77,
#   7,
#   196,
#   113,
#   56,
#   1,
#   114,
#   2,
#   25,
#   1,
#   24,
#   32,
#   197,
#   2,
#   10,
#   36,
#   102,
#   2],
#  [75,
#   48,
#   1,
#   74,
#   77,
#   7,
#   196,
#   113,
#   56,
#   1,
#   114,
#   2,
#   25,
#   1,
#   24,
#   32,
#   197,
#   2,
#   10,
#   36,
#   102,
#   2,
#   73],
#  [75,
#   48,
#   1,
#   74,
#   77,
#   7,
#   196,
#   113,
#   56,
#   1,
#   114,
#   2,
#   25,
#   1,
#   24,
#   32,
#   197,
#   2,
#   10,
#   36,
#   102,
#   2,
#   73,
#   6],
#  [75,
#   48,
#   1,
#   74,
#   77,
#   7,
#   196,
#   113,
#   56,
#   1,
#   114,
#   2,
#   25,
#   1,
#   24,
#   32,
#   197,
#   2,
#   10,
#   36,
#   102,
#   2,
#   73,
#   6,
#   4],
#  [75,
#   48,
#   1,
#   74,
#   77,
#   7,
#   196,
#   113,
#   56,
#   1,
#   114,
#   2,
#   25,
#   1,
#   24,
#   32,
#   197,
#   2,
#   10,
#   36,
#   102,
#   2,
#   73,
#   6,
#   4,
#   198],
#  [75,
#   48,
#   1,
#   74,
#   77,
#   7,
#   196,
#   113,
#   56,
#   1,
#   114,
#   2,
#   25,
#   1,
#   24,
#   32,
#   197,
#   2,
#   10,
#   36,
#   102,
#   2,
#   73,
#   6,
#   4,
#   198,
#   14],
#  [75,
#   48,
#   1,
#   74,
#   77,
#   7,
#   196,
#   113,
#   56,
#   1,
#   114,
#   2,
#   25,
#   1,
#   24,
#   32,
#   197,
#   2,
#   10,
#   36,
#   102,
#   2,
#   73,
#   6,
#   4,
#   198,
#   14,
#   5],
#  [75,
#   48,
#   1,
#   74,
#   77,
#   7,
#   196,
#   113,
#   56,
#   1,
#   114,
#   2,
#   25,
#   1,
#   24,
#   32,
#   197,
#   2,
#   10,
#   36,
#   102,
#   2,
#   73,
#   6,
#   4,
#   198,
#   14,
#   5,
#   63],
#  [75,
#   48,
#   1,
#   74,
#   77,
#   7,
#   196,
#   113,
#   56,
#   1,
#   114,
#   2,
#   25,
#   1,
#   24,
#   32,
#   197,
#   2,
#   10,
#   36,
#   102,
#   2,
#   73,
#   6,
#   4,
#   198,
#   14,
#   5,
#   63,
#   4],
#  [75,
#   48,
#   1,
#   74,
#   77,
#   7,
#   196,
#   113,
#   56,
#   1,
#   114,
#   2,
#   25,
#   1,
#   24,
#   32,
#   197,
#   2,
#   10,
#   36,
#   102,
#   2,
#   73,
#   6,
#   4,
#   198,
#   14,
#   5,
#   63,
#   4,
#   199],
#  [11, 19],
#  [11, 19, 3],
#  [11, 19, 3, 73],
#  [11, 19, 3, 73, 200],
#  [11, 19, 3, 73, 200, 1],
#  [11, 19, 3, 73, 200, 1, 12],
#  [11, 19, 3, 73, 200, 1, 12, 78],
#  [11, 19, 3, 73, 200, 1, 12, 78, 201],
#  [11, 19, 3, 73, 200, 1, 12, 78, 201, 1],
#  [11, 19, 3, 73, 200, 1, 12, 78, 201, 1, 24],
#  [11, 19, 3, 73, 200, 1, 12, 78, 201, 1, 24, 11],
#  [11, 19, 3, 73, 200, 1, 12, 78, 201, 1, 24, 11, 7],
#  [11, 19, 3, 73, 200, 1, 12, 78, 201, 1, 24, 11, 7, 1],
#  [11, 19, 3, 73, 200, 1, 12, 78, 201, 1, 24, 11, 7, 1, 115],
#  [11, 19, 3, 73, 200, 1, 12, 78, 201, 1, 24, 11, 7, 1, 115, 202],
#  [2, 43],
#  [2, 43, 5],
#  [2, 43, 5, 51],
#  [2, 43, 5, 51, 113],
#  [2, 43, 5, 51, 113, 115],
#  [2, 43, 5, 51, 113, 115, 77],
#  [2, 43, 5, 51, 113, 115, 77, 56],
#  [2, 43, 5, 51, 113, 115, 77, 56, 1],
#  [2, 43, 5, 51, 113, 115, 77, 56, 1, 114],
#  [2, 43, 5, 51, 113, 115, 77, 56, 1, 114, 2],
#  [2, 43, 5, 51, 113, 115, 77, 56, 1, 114, 2, 6],
#  [2, 43, 5, 51, 113, 115, 77, 56, 1, 114, 2, 6, 203],
#  [2, 43, 5, 51, 113, 115, 77, 56, 1, 114, 2, 6, 203, 1],
#  [2, 43, 5, 51, 113, 115, 77, 56, 1, 114, 2, 6, 203, 1, 24],
#  [3, 22],
#  [3, 22, 116],
#  [3, 22, 116, 117],
#  [3, 22, 116, 117, 118],
#  [3, 22, 116, 117, 118, 18],
#  [3, 22, 116, 117, 118, 18, 3],
#  [3, 22, 116, 117, 118, 18, 3, 22],
#  [3, 22, 116, 117, 118, 18, 3, 22, 42],
#  [3, 22, 116, 117, 118, 18, 3, 22, 42, 37],
#  [3, 22, 116, 117, 118, 18, 3, 22, 42, 37, 4],
#  [3, 22, 116, 117, 118, 18, 3, 22, 42, 37, 4, 25],
#  [3, 22, 116, 117, 118, 18, 3, 22, 42, 37, 4, 25, 1],
#  [3, 22, 116, 117, 118, 18, 3, 22, 42, 37, 4, 25, 1, 24],
#  [3, 22, 116, 117, 118, 18, 3, 22, 42, 37, 4, 25, 1, 24, 16],
#  [3, 22, 116, 117, 118, 18, 3, 22, 42, 37, 4, 25, 1, 24, 16, 1],
#  [3, 22, 116, 117, 118, 18, 3, 22, 42, 37, 4, 25, 1, 24, 16, 1, 47],
#  [3, 22, 116, 117, 118, 18, 3, 22, 42, 37, 4, 25, 1, 24, 16, 1, 47, 11],
#  [3, 22, 116, 117, 118, 18, 3, 22, 42, 37, 4, 25, 1, 24, 16, 1, 47, 11, 119],
#  [3,
#   22,
#   116,
#   117,
#   118,
#   18,
#   3,
#   22,
#   42,
#   37,
#   4,
#   25,
#   1,
#   24,
#   16,
#   1,
#   47,
#   11,
#   119,
#   3],
#  [3,
#   22,
#   116,
#   117,
#   118,
#   18,
#   3,
#   22,
#   42,
#   37,
#   4,
#   25,
#   1,
#   24,
#   16,
#   1,
#   47,
#   11,
#   119,
#   3,
#   28],
#  [2, 6],
#  [2, 6, 4],
#  [2, 6, 4, 57],
#  [2, 6, 4, 57, 79],
#  [2, 6, 4, 57, 79, 69],
#  [2, 6, 4, 57, 79, 69, 120],
#  [2, 6, 4, 57, 79, 69, 120, 5],
#  [2, 6, 4, 57, 79, 69, 120, 5, 55],
#  [204, 106],
#  [204, 106, 121],
#  [80, 205],
#  [80, 205, 10],
#  [80, 205, 10, 3],
#  [80, 205, 10, 3, 206],
#  [80, 205, 10, 3, 206, 1],
#  [80, 205, 10, 3, 206, 1, 35],
#  [80, 205, 10, 3, 206, 1, 35, 122],
#  [80, 205, 10, 3, 206, 1, 35, 122, 16],
#  [80, 205, 10, 3, 206, 1, 35, 122, 16, 1],
#  [80, 205, 10, 3, 206, 1, 35, 122, 16, 1, 47],
#  [27, 207],
#  [27, 207, 7],
#  [27, 207, 7, 208],
#  [27, 207, 7, 208, 32],
#  [27, 207, 7, 208, 32, 123],
#  [27, 207, 7, 208, 32, 123, 209],
#  [27, 207, 7, 208, 32, 123, 209, 2],
#  [27, 207, 7, 208, 32, 123, 209, 2, 10],
#  [27, 207, 7, 208, 32, 123, 209, 2, 10, 54],
#  [27, 207, 7, 208, 32, 123, 209, 2, 10, 54, 1],
#  [27, 207, 7, 208, 32, 123, 209, 2, 10, 54, 1, 122],
#  [27, 207, 7, 208, 32, 123, 209, 2, 10, 54, 1, 122, 80],
#  [27, 207, 7, 208, 32, 123, 209, 2, 10, 54, 1, 122, 80, 38],
#  [27, 207, 7, 208, 32, 123, 209, 2, 10, 54, 1, 122, 80, 38, 29],
#  [27, 207, 7, 208, 32, 123, 209, 2, 10, 54, 1, 122, 80, 38, 29, 7],
#  [27, 207, 7, 208, 32, 123, 209, 2, 10, 54, 1, 122, 80, 38, 29, 7, 210],
#  [27, 207, 7, 208, 32, 123, 209, 2, 10, 54, 1, 122, 80, 38, 29, 7, 210, 111],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35,
#   21],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35,
#   21,
#   15],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35,
#   21,
#   15,
#   1],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35,
#   21,
#   15,
#   1,
#   77],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35,
#   21,
#   15,
#   1,
#   77,
#   8],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35,
#   21,
#   15,
#   1,
#   77,
#   8,
#   81],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35,
#   21,
#   15,
#   1,
#   77,
#   8,
#   81,
#   76],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35,
#   21,
#   15,
#   1,
#   77,
#   8,
#   81,
#   76,
#   4],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35,
#   21,
#   15,
#   1,
#   77,
#   8,
#   81,
#   76,
#   4,
#   212],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35,
#   21,
#   15,
#   1,
#   77,
#   8,
#   81,
#   76,
#   4,
#   212,
#   48],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35,
#   21,
#   15,
#   1,
#   77,
#   8,
#   81,
#   76,
#   4,
#   212,
#   48,
#   124],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35,
#   21,
#   15,
#   1,
#   77,
#   8,
#   81,
#   76,
#   4,
#   212,
#   48,
#   124,
#   78],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35,
#   21,
#   15,
#   1,
#   77,
#   8,
#   81,
#   76,
#   4,
#   212,
#   48,
#   124,
#   78,
#   81],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35,
#   21,
#   15,
#   1,
#   77,
#   8,
#   81,
#   76,
#   4,
#   212,
#   48,
#   124,
#   78,
#   81,
#   48],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35,
#   21,
#   15,
#   1,
#   77,
#   8,
#   81,
#   76,
#   4,
#   212,
#   48,
#   124,
#   78,
#   81,
#   48,
#   2],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35,
#   21,
#   15,
#   1,
#   77,
#   8,
#   81,
#   76,
#   4,
#   212,
#   48,
#   124,
#   78,
#   81,
#   48,
#   2,
#   9],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35,
#   21,
#   15,
#   1,
#   77,
#   8,
#   81,
#   76,
#   4,
#   212,
#   48,
#   124,
#   78,
#   81,
#   48,
#   2,
#   9,
#   6],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35,
#   21,
#   15,
#   1,
#   77,
#   8,
#   81,
#   76,
#   4,
#   212,
#   48,
#   124,
#   78,
#   81,
#   48,
#   2,
#   9,
#   6,
#   4],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35,
#   21,
#   15,
#   1,
#   77,
#   8,
#   81,
#   76,
#   4,
#   212,
#   48,
#   124,
#   78,
#   81,
#   48,
#   2,
#   9,
#   6,
#   4,
#   213],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35,
#   21,
#   15,
#   1,
#   77,
#   8,
#   81,
#   76,
#   4,
#   212,
#   48,
#   124,
#   78,
#   81,
#   48,
#   2,
#   9,
#   6,
#   4,
#   213,
#   1],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35,
#   21,
#   15,
#   1,
#   77,
#   8,
#   81,
#   76,
#   4,
#   212,
#   48,
#   124,
#   78,
#   81,
#   48,
#   2,
#   9,
#   6,
#   4,
#   213,
#   1,
#   29],
#  [27,
#   207,
#   7,
#   208,
#   32,
#   123,
#   209,
#   2,
#   10,
#   54,
#   1,
#   122,
#   80,
#   38,
#   29,
#   7,
#   210,
#   111,
#   2,
#   6,
#   211,
#   29,
#   16,
#   81,
#   76,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   20,
#   1,
#   46,
#   35,
#   21,
#   15,
#   1,
#   77,
#   8,
#   81,
#   76,
#   4,
#   212,
#   48,
#   124,
#   78,
#   81,
#   48,
#   2,
#   9,
#   6,
#   4,
#   213,
#   1,
#   29,
#   112],
#  [124, 45],
#  [124, 45, 1],
#  [124, 45, 1, 12],
#  [124, 45, 1, 12, 7],
#  [124, 45, 1, 12, 7, 214],
#  [124, 45, 1, 12, 7, 214, 18],
#  [124, 45, 1, 12, 7, 214, 18, 2],
#  [124, 45, 1, 12, 7, 214, 18, 2, 6],
#  [124, 45, 1, 12, 7, 214, 18, 2, 6, 35],
#  [124, 45, 1, 12, 7, 214, 18, 2, 6, 35, 79],
#  [124, 45, 1, 12, 7, 214, 18, 2, 6, 35, 79, 31],
#  [124, 45, 1, 12, 7, 214, 18, 2, 6, 35, 79, 31, 52],
#  [124, 45, 1, 12, 7, 214, 18, 2, 6, 35, 79, 31, 52, 58],
#  [124, 45, 1, 12, 7, 214, 18, 2, 6, 35, 79, 31, 52, 58, 51],
#  [124, 45, 1, 12, 7, 214, 18, 2, 6, 35, 79, 31, 52, 58, 51, 215],
#  [124, 45, 1, 12, 7, 214, 18, 2, 6, 35, 79, 31, 52, 58, 51, 215, 8],
#  [124, 45, 1, 12, 7, 214, 18, 2, 6, 35, 79, 31, 52, 58, 51, 215, 8, 31],
#  [124, 45, 1, 12, 7, 214, 18, 2, 6, 35, 79, 31, 52, 58, 51, 215, 8, 31, 62],
#  [124, 45, 1, 12, 7, 214, 18, 2, 6, 35, 79, 31, 52, 58, 51, 215, 8, 31, 62, 2],
#  [124,
#   45,
#   1,
#   12,
#   7,
#   214,
#   18,
#   2,
#   6,
#   35,
#   79,
#   31,
#   52,
#   58,
#   51,
#   215,
#   8,
#   31,
#   62,
#   2,
#   9],
#  [124,
#   45,
#   1,
#   12,
#   7,
#   214,
#   18,
#   2,
#   6,
#   35,
#   79,
#   31,
#   52,
#   58,
#   51,
#   215,
#   8,
#   31,
#   62,
#   2,
#   9,
#   17],
#  [124,
#   45,
#   1,
#   12,
#   7,
#   214,
#   18,
#   2,
#   6,
#   35,
#   79,
#   31,
#   52,
#   58,
#   51,
#   215,
#   8,
#   31,
#   62,
#   2,
#   9,
#   17,
#   37],
#  [124,
#   45,
#   1,
#   12,
#   7,
#   214,
#   18,
#   2,
#   6,
#   35,
#   79,
#   31,
#   52,
#   58,
#   51,
#   215,
#   8,
#   31,
#   62,
#   2,
#   9,
#   17,
#   37,
#   4],
#  [124,
#   45,
#   1,
#   12,
#   7,
#   214,
#   18,
#   2,
#   6,
#   35,
#   79,
#   31,
#   52,
#   58,
#   51,
#   215,
#   8,
#   31,
#   62,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54],
#  [124,
#   45,
#   1,
#   12,
#   7,
#   214,
#   18,
#   2,
#   6,
#   35,
#   79,
#   31,
#   52,
#   58,
#   51,
#   215,
#   8,
#   31,
#   62,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   1],
#  [124,
#   45,
#   1,
#   12,
#   7,
#   214,
#   18,
#   2,
#   6,
#   35,
#   79,
#   31,
#   52,
#   58,
#   51,
#   215,
#   8,
#   31,
#   62,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   1,
#   35],
#  [124,
#   45,
#   1,
#   12,
#   7,
#   214,
#   18,
#   2,
#   6,
#   35,
#   79,
#   31,
#   52,
#   58,
#   51,
#   215,
#   8,
#   31,
#   62,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   1,
#   35,
#   21],
#  [124,
#   45,
#   1,
#   12,
#   7,
#   214,
#   18,
#   2,
#   6,
#   35,
#   79,
#   31,
#   52,
#   58,
#   51,
#   215,
#   8,
#   31,
#   62,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   1,
#   35,
#   21,
#   80],
#  [124,
#   45,
#   1,
#   12,
#   7,
#   214,
#   18,
#   2,
#   6,
#   35,
#   79,
#   31,
#   52,
#   58,
#   51,
#   215,
#   8,
#   31,
#   62,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   1,
#   35,
#   21,
#   80,
#   216],
#  [124,
#   45,
#   1,
#   12,
#   7,
#   214,
#   18,
#   2,
#   6,
#   35,
#   79,
#   31,
#   52,
#   58,
#   51,
#   215,
#   8,
#   31,
#   62,
#   2,
#   9,
#   17,
#   37,
#   4,
#   54,
#   1,
#   35,
#   21,
#   80,
#   216,
#   217],
#  [218, 219],
#  [218, 219, 74],
#  [218, 219, 74, 7],
#  [218, 219, 74, 7, 42],
#  [218, 219, 74, 7, 42, 125],
#  [220, 8],
#  [220, 8, 1],
#  [220, 8, 1, 221],
#  [220, 8, 1, 221, 12],
#  [220, 8, 1, 221, 12, 40],
#  [30, 10],
#  [30, 10, 3],
#  [30, 10, 3, 222],
#  [30, 10, 3, 222, 223],
#  [30, 10, 3, 222, 223, 15],
#  [30, 10, 3, 222, 223, 15, 67],
#  [30, 10, 3, 222, 223, 15, 67, 8],
#  [30, 10, 3, 222, 223, 15, 67, 8, 5],
#  [30, 10, 3, 222, 223, 15, 67, 8, 5, 59],
#  [30, 10, 3, 222, 223, 15, 67, 8, 5, 59, 78],
#  [30, 10, 3, 222, 223, 15, 67, 8, 5, 59, 78, 1],
#  [30, 10, 3, 222, 223, 15, 67, 8, 5, 59, 78, 1, 33],
#  [2, 9],
#  [2, 9, 6],
#  [2, 9, 6, 4],
#  [2, 9, 6, 4, 224],
#  [2, 9, 6, 4, 224, 5],
#  [2, 9, 6, 4, 224, 5, 126],
#  [2, 9, 6, 4, 224, 5, 126, 127],
#  [2, 9, 6, 4, 224, 5, 126, 127, 125],
#  [2, 9, 6, 4, 224, 5, 126, 127, 125, 15],
#  [2, 9, 6, 4, 224, 5, 126, 127, 125, 15, 38],
#  [2, 9, 6, 4, 224, 5, 126, 127, 125, 15, 38, 71],
#  [2, 9, 6, 4, 224, 5, 126, 127, 125, 15, 38, 71, 18],
#  [2, 9, 6, 4, 224, 5, 126, 127, 125, 15, 38, 71, 18, 34],
#  [2, 9, 6, 4, 224, 5, 126, 127, 125, 15, 38, 71, 18, 34, 225],
#  [2, 9, 6, 4, 224, 5, 126, 127, 125, 15, 38, 71, 18, 34, 225, 9],
#  [2, 9, 6, 4, 224, 5, 126, 127, 125, 15, 38, 71, 18, 34, 225, 9, 57],
#  [2, 9, 6, 4, 224, 5, 126, 127, 125, 15, 38, 71, 18, 34, 225, 9, 57, 2],
#  [2, 9, 6, 4, 224, 5, 126, 127, 125, 15, 38, 71, 18, 34, 225, 9, 57, 2, 14],
#  [2, 9, 6, 4, 224, 5, 126, 127, 125, 15, 38, 71, 18, 34, 225, 9, 57, 2, 14, 5],
#  [2,
#   9,
#   6,
#   4,
#   224,
#   5,
#   126,
#   127,
#   125,
#   15,
#   38,
#   71,
#   18,
#   34,
#   225,
#   9,
#   57,
#   2,
#   14,
#   5,
#   128],
#  [2,
#   9,
#   6,
#   4,
#   224,
#   5,
#   126,
#   127,
#   125,
#   15,
#   38,
#   71,
#   18,
#   34,
#   225,
#   9,
#   57,
#   2,
#   14,
#   5,
#   128,
#   16],
#  [2,
#   9,
#   6,
#   4,
#   224,
#   5,
#   126,
#   127,
#   125,
#   15,
#   38,
#   71,
#   18,
#   34,
#   225,
#   9,
#   57,
#   2,
#   14,
#   5,
#   128,
#   16,
#   128],
#  [2,
#   9,
#   6,
#   4,
#   224,
#   5,
#   126,
#   127,
#   125,
#   15,
#   38,
#   71,
#   18,
#   34,
#   225,
#   9,
#   57,
#   2,
#   14,
#   5,
#   128,
#   16,
#   128,
#   59],
#  [2,
#   9,
#   6,
#   4,
#   224,
#   5,
#   126,
#   127,
#   125,
#   15,
#   38,
#   71,
#   18,
#   34,
#   225,
#   9,
#   57,
#   2,
#   14,
#   5,
#   128,
#   16,
#   128,
#   59,
#   129],
#  [2,
#   9,
#   6,
#   4,
#   224,
#   5,
#   126,
#   127,
#   125,
#   15,
#   38,
#   71,
#   18,
#   34,
#   225,
#   9,
#   57,
#   2,
#   14,
#   5,
#   128,
#   16,
#   128,
#   59,
#   129,
#   33],
#  [19, 3],
#  [19, 3, 36],
#  [19, 3, 36, 1],
#  [19, 3, 36, 1, 13],
#  [19, 3, 36, 1, 13, 70],
#  [19, 3, 36, 1, 13, 70, 10],
#  [19, 3, 36, 1, 13, 70, 10, 3],
#  [19, 3, 36, 1, 13, 70, 10, 3, 226],
#  [19, 3, 36, 1, 13, 70, 10, 3, 226, 227],
#  [19, 3, 36, 1, 13, 70, 10, 3, 226, 227, 46],
#  [19, 3, 36, 1, 13, 70, 10, 3, 226, 227, 46, 130],
#  [19, 3, 36, 1, 13, 70, 10, 3, 226, 227, 46, 130, 228],
#  [44, 131],
#  [44, 131, 229],
#  [44, 131, 229, 46],
#  [44, 131, 229, 46, 130],
#  [44, 131, 229, 46, 130, 59],
#  [44, 131, 229, 46, 130, 59, 15],
#  [44, 131, 229, 46, 130, 59, 15, 1],
#  [44, 131, 229, 46, 130, 59, 15, 1, 59],
#  [44, 131, 229, 46, 130, 59, 15, 1, 59, 129],
#  [44, 131, 229, 46, 130, 59, 15, 1, 59, 129, 126],
#  [44, 131, 229, 46, 130, 59, 15, 1, 59, 129, 126, 127],
#  [3, 22],
#  [3, 22, 116],
#  [3, 22, 116, 117],
#  [3, 22, 116, 117, 118],
#  [3, 22, 116, 117, 118, 18],
#  [3, 22, 116, 117, 118, 18, 3],
#  [3, 22, 116, 117, 118, 18, 3, 22],
#  [3, 22, 116, 117, 118, 18, 3, 22, 42],
#  [3, 22, 116, 117, 118, 18, 3, 22, 42, 37],
#  [3, 22, 116, 117, 118, 18, 3, 22, 42, 37, 4],
#  [3, 22, 116, 117, 118, 18, 3, 22, 42, 37, 4, 25],
#  [3, 22, 116, 117, 118, 18, 3, 22, 42, 37, 4, 25, 1],
#  [3, 22, 116, 117, 118, 18, 3, 22, 42, 37, 4, 25, 1, 24],
#  [3, 22, 116, 117, 118, 18, 3, 22, 42, 37, 4, 25, 1, 24, 16],
#  [3, 22, 116, 117, 118, 18, 3, 22, 42, 37, 4, 25, 1, 24, 16, 1],
#  [3, 22, 116, 117, 118, 18, 3, 22, 42, 37, 4, 25, 1, 24, 16, 1, 47],
#  [3, 22, 116, 117, 118, 18, 3, 22, 42, 37, 4, 25, 1, 24, 16, 1, 47, 11],
#  [3, 22, 116, 117, 118, 18, 3, 22, 42, 37, 4, 25, 1, 24, 16, 1, 47, 11, 119],
#  [3,
#   22,
#   116,
#   117,
#   118,
#   18,
#   3,
#   22,
#   42,
#   37,
#   4,
#   25,
#   1,
#   24,
#   16,
#   1,
#   47,
#   11,
#   119,
#   3],
#  [3,
#   22,
#   116,
#   117,
#   118,
#   18,
#   3,
#   22,
#   42,
#   37,
#   4,
#   25,
#   1,
#   24,
#   16,
#   1,
#   47,
#   11,
#   119,
#   3,
#   28],
#  [2, 6],
#  [2, 6, 4],
#  [2, 6, 4, 57],
#  [2, 6, 4, 57, 79],
#  [2, 6, 4, 57, 79, 69],
#  [2, 6, 4, 57, 79, 69, 120],
#  [2, 6, 4, 57, 79, 69, 120, 5],
#  [2, 6, 4, 57, 79, 69, 120, 5, 55],
#  [132, 18],
#  [132, 18, 39],
#  [132, 18, 39, 49],
#  [132, 18, 39, 49, 107],
#  [132, 18, 39, 49, 107, 121],
#  [11, 7],
#  [11, 7, 1],
#  [11, 7, 1, 230],
#  [11, 7, 1, 230, 4],
#  [11, 7, 1, 230, 4, 43],
#  [11, 7, 1, 230, 4, 43, 1],
#  [11, 7, 1, 230, 4, 43, 1, 132],
#  [231, 53],
#  [231, 53, 98],
#  [231, 53, 98, 232],
#  [2, 6],
#  [2, 6, 4],
#  [2, 6, 4, 23],
#  [2, 6, 4, 23, 1],
#  [2, 6, 4, 23, 1, 110],
#  [2, 6, 4, 23, 1, 110, 40],
#  [2, 6, 4, 23, 1, 110, 40, 8],
#  [2, 6, 4, 23, 1, 110, 40, 8, 31],
#  [2, 6, 4, 23, 1, 110, 40, 8, 31, 52],
#  [2, 6],
#  [2, 6, 4],
#  [2, 6, 4, 233],
#  [2, 6, 4, 233, 20],
#  [2, 6, 4, 233, 20, 1],
#  [2, 6, 4, 233, 20, 1, 12],
#  [2, 6, 4, 233, 20, 1, 12, 234],
#  [3, 22],
#  [3, 22, 235],
#  [3, 22, 235, 70],
#  [3, 22, 235, 70, 99],
#  [3, 22, 235, 70, 99, 10],
#  [3, 22, 235, 70, 99, 10, 3],
#  [3, 22, 235, 70, 99, 10, 3, 23],
#  [3, 22, 235, 70, 99, 10, 3, 23, 24],
#  [3, 22, 235, 70, 99, 10, 3, 23, 24, 8],
#  [3, 22, 235, 70, 99, 10, 3, 23, 24, 8, 1],
#  [3, 22, 235, 70, 99, 10, 3, 23, 24, 8, 1, 133],
#  [3, 22, 235, 70, 99, 10, 3, 23, 24, 8, 1, 133, 65],
#  [2, 9],
#  [2, 9, 43],
#  [2, 9, 43, 5],
#  [2, 9, 43, 5, 109],
#  [2, 9, 43, 5, 109, 4],
#  [2, 9, 43, 5, 109, 4, 23],
#  [2, 9, 43, 5, 109, 4, 23, 40],
#  [2, 9, 43, 5, 109, 4, 23, 40, 8],
#  [2, 9, 43, 5, 109, 4, 23, 40, 8, 133],
#  [2, 9, 43, 5, 109, 4, 23, 40, 8, 133, 65],
#  [2, 9, 43, 5, 109, 4, 23, 40, 8, 133, 65, 15],
#  [2, 9, 43, 5, 109, 4, 23, 40, 8, 133, 65, 15, 38],
#  [2, 9, 43, 5, 109, 4, 23, 40, 8, 133, 65, 15, 38, 71],
#  [2, 9, 43, 5, 109, 4, 23, 40, 8, 133, 65, 15, 38, 71, 45],
#  [2, 9, 43, 5, 109, 4, 23, 40, 8, 133, 65, 15, 38, 71, 45, 2],
#  [2, 9, 43, 5, 109, 4, 23, 40, 8, 133, 65, 15, 38, 71, 45, 2, 23],
#  [2, 9, 43, 5, 109, 4, 23, 40, 8, 133, 65, 15, 38, 71, 45, 2, 23, 14],
#  [2, 9, 43, 5, 109, 4, 23, 40, 8, 133, 65, 15, 38, 71, 45, 2, 23, 14, 1],
#  [2, 9, 43, 5, 109, 4, 23, 40, 8, 133, 65, 15, 38, 71, 45, 2, 23, 14, 1, 236],
#  [2,
#   9,
#   43,
#   5,
#   109,
#   4,
#   23,
#   40,
#   8,
#   133,
#   65,
#   15,
#   38,
#   71,
#   45,
#   2,
#   23,
#   14,
#   1,
#   236,
#   63],
#  [3, 6],
#  [3, 6, 123],
#  [3, 6, 123, 82],
#  [3, 6, 123, 82, 39],
#  [3, 6, 123, 82, 39, 49],
#  [3, 6, 123, 82, 39, 49, 7],
#  [3, 6, 123, 82, 39, 49, 7, 5],
#  [3, 6, 123, 82, 39, 49, 7, 5, 68],
#  [3, 6, 123, 82, 39, 49, 7, 5, 68, 8],
#  [3, 6, 123, 82, 39, 49, 7, 5, 68, 8, 27],
#  [3, 6, 123, 82, 39, 49, 7, 5, 68, 8, 27, 13],
#  [3, 6, 123, 82, 39, 49, 7, 5, 68, 8, 27, 13, 11],
#  [3, 6, 123, 82, 39, 49, 7, 5, 68, 8, 27, 13, 11, 134],
#  [3, 6, 123, 82, 39, 49, 7, 5, 68, 8, 27, 13, 11, 134, 135],
#  [3, 6, 123, 82, 39, 49, 7, 5, 68, 8, 27, 13, 11, 134, 135, 39],
#  [3, 6, 123, 82, 39, 49, 7, 5, 68, 8, 27, 13, 11, 134, 135, 39, 49],
#  [27, 7],
#  [27, 7, 4],
#  [27, 7, 4, 237],
#  [27, 7, 4, 237, 82],
#  [27, 7, 4, 237, 82, 39],
#  [27, 7, 4, 237, 82, 39, 49],
#  [27, 7, 4, 237, 82, 39, 49, 238],
#  [27, 7, 4, 237, 82, 39, 49, 238, 42],
#  [27, 7, 4, 237, 82, 39, 49, 238, 42, 239],
#  [27, 7, 4, 237, 82, 39, 49, 238, 42, 239, 39],
#  [27, 7, 4, 237, 82, 39, 49, 238, 42, 239, 39, 136],
#  [27, 7, 4, 237, 82, 39, 49, 238, 42, 239, 39, 136, 32],
#  [27, 7, 4, 237, 82, 39, 49, 238, 42, 239, 39, 136, 32, 26],
#  [27, 7, 4, 237, 82, 39, 49, 238, 42, 239, 39, 136, 32, 26, 240],
#  [27, 7, 4, 237, 82, 39, 49, 238, 42, 239, 39, 136, 32, 26, 240, 136],
#  [27, 7, 4, 237, 82, 39, 49, 238, 42, 239, 39, 136, 32, 26, 240, 136, 2],
#  [27, 7, 4, 237, 82, 39, 49, 238, 42, 239, 39, 136, 32, 26, 240, 136, 2, 241],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53,
#   246],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53,
#   246,
#   4],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53,
#   246,
#   4,
#   36],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53,
#   246,
#   4,
#   36,
#   27],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53,
#   246,
#   4,
#   36,
#   27,
#   12],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53,
#   246,
#   4,
#   36,
#   27,
#   12,
#   131],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53,
#   246,
#   4,
#   36,
#   27,
#   12,
#   131,
#   14],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53,
#   246,
#   4,
#   36,
#   27,
#   12,
#   131,
#   14,
#   247],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53,
#   246,
#   4,
#   36,
#   27,
#   12,
#   131,
#   14,
#   247,
#   3],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53,
#   246,
#   4,
#   36,
#   27,
#   12,
#   131,
#   14,
#   247,
#   3,
#   22],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53,
#   246,
#   4,
#   36,
#   27,
#   12,
#   131,
#   14,
#   247,
#   3,
#   22,
#   248],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53,
#   246,
#   4,
#   36,
#   27,
#   12,
#   131,
#   14,
#   247,
#   3,
#   22,
#   248,
#   2],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53,
#   246,
#   4,
#   36,
#   27,
#   12,
#   131,
#   14,
#   247,
#   3,
#   22,
#   248,
#   2,
#   9],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53,
#   246,
#   4,
#   36,
#   27,
#   12,
#   131,
#   14,
#   247,
#   3,
#   22,
#   248,
#   2,
#   9,
#   17],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53,
#   246,
#   4,
#   36,
#   27,
#   12,
#   131,
#   14,
#   247,
#   3,
#   22,
#   248,
#   2,
#   9,
#   17,
#   249],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53,
#   246,
#   4,
#   36,
#   27,
#   12,
#   131,
#   14,
#   247,
#   3,
#   22,
#   248,
#   2,
#   9,
#   17,
#   249,
#   108],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53,
#   246,
#   4,
#   36,
#   27,
#   12,
#   131,
#   14,
#   247,
#   3,
#   22,
#   248,
#   2,
#   9,
#   17,
#   249,
#   108,
#   7],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53,
#   246,
#   4,
#   36,
#   27,
#   12,
#   131,
#   14,
#   247,
#   3,
#   22,
#   248,
#   2,
#   9,
#   17,
#   249,
#   108,
#   7,
#   11],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53,
#   246,
#   4,
#   36,
#   27,
#   12,
#   131,
#   14,
#   247,
#   3,
#   22,
#   248,
#   2,
#   9,
#   17,
#   249,
#   108,
#   7,
#   11,
#   134],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53,
#   246,
#   4,
#   36,
#   27,
#   12,
#   131,
#   14,
#   247,
#   3,
#   22,
#   248,
#   2,
#   9,
#   17,
#   249,
#   108,
#   7,
#   11,
#   134,
#   135],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53,
#   246,
#   4,
#   36,
#   27,
#   12,
#   131,
#   14,
#   247,
#   3,
#   22,
#   248,
#   2,
#   9,
#   17,
#   249,
#   108,
#   7,
#   11,
#   134,
#   135,
#   39],
#  [27,
#   7,
#   4,
#   237,
#   82,
#   39,
#   49,
#   238,
#   42,
#   239,
#   39,
#   136,
#   32,
#   26,
#   240,
#   136,
#   2,
#   241,
#   242,
#   58,
#   14,
#   82,
#   243,
#   96,
#   244,
#   245,
#   32,
#   19,
#   2,
#   53,
#   246,
#   4,
#   36,
#   27,
#   12,
#   131,
#   14,
#   247,
#   3,
#   22,
#   248,
#   2,
#   9,
#   17,
#   249,
#   108,
#   7,
#   11,
#   134,
#   135,
#   39,
#   49],
#  [250, 251],
#  [250, 251, 21],
#  [252, 253],
#  [252, 253, 21],
#  [21, 105],
#  [21, 105, 254],
#  [21, 105, 254, 255],
#  [256, 16],
#  [256, 16, 257],
#  [256, 16, 257, 258],
#  [256, 16, 257, 258, 259]]

# %%
max_len = max([len(x) for x in input_sequences])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen = max_len, padding='pre')

# %%
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0,  83,   1],
#        [  0,   0,   0, ...,  83,   1,  13],
#        [  0,   0,   0, ...,   0,  11,   7],
#        ...,
#        [  0,   0,   0, ..., 256,  16, 257],
#        [  0,   0,   0, ...,  16, 257, 258],
#        [  0,   0,   0, ..., 257, 258, 259]], dtype=int32)

# %%
X = padded_input_sequences[:,:-1]

# %%
y = padded_input_sequences[:,-1]

# %%
X.shape
# Out:
# (792, 56)

# %%
y.shape
# Out:
# (792,)

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y,num_classes=283)

# %%
y.shape
# Out:
# (792, 283)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# %%
model = Sequential()
model.add(Embedding(283, 100))
model.add(LSTM(150, return_sequences=True))
model.add(LSTM(150))
model.add(Dense(283, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.0628 - loss: 5.5261
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.0754 - loss: 5.0577
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0807 - loss: 4.9526
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0768 - loss: 4.8977
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0890 - loss: 4.7829
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0772 - loss: 4.7791
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.0683 - loss: 4.7358
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0857 - loss: 4.5971
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0729 - loss: 4.5231
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0907 - loss: 4.4448
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.0833 - loss: 4.4001
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1026 - loss: 4.1822
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1165 - loss: 4.1167
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1185 - loss: 4.0334
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1091 - loss: 3.9328
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1281 - loss: 3.7979
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1522 - loss: 3.6979
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1579 - loss: 3.6648
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1818 - loss: 3.4394
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.1984 - loss: 3.3771
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2199 - loss: 3.2857
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2296 - loss: 3.1589
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.2729 - loss: 3.0773
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.2763 - loss: 2.9436
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3023 - loss: 2.8768
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3592 - loss: 2.7992
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3490 - loss: 2.7412
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4133 - loss: 2.5871
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4132 - loss: 2.4875
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4670 - loss: 2.3413
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4436 - loss: 2.3291
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5289 - loss: 2.1658
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5321 - loss: 2.1108
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5835 - loss: 1.9771
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6029 - loss: 1.9528
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6052 - loss: 1.8648
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6743 - loss: 1.6996
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6663 - loss: 1.6928
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7125 - loss: 1.5924
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7296 - loss: 1.5089
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7591 - loss: 1.4348
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7476 - loss: 1.4307
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7762 - loss: 1.3415
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7967 - loss: 1.3039
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8241 - loss: 1.1937
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8192 - loss: 1.2009
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8278 - loss: 1.1105
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8521 - loss: 1.0709
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8588 - loss: 0.9884
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8645 - loss: 0.9387
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8658 - loss: 0.9482
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8868 - loss: 0.8452
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8800 - loss: 0.8565
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8832 - loss: 0.8196
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8929 - loss: 0.7544
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8761 - loss: 0.7834
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8937 - loss: 0.6934
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8947 - loss: 0.7035
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8975 - loss: 0.6797
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9232 - loss: 0.5903
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9177 - loss: 0.5979
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9053 - loss: 0.5975
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9284 - loss: 0.5537
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9325 - loss: 0.5219
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9238 - loss: 0.5071
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9263 - loss: 0.4842
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9153 - loss: 0.5036
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9286 - loss: 0.4462
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9437 - loss: 0.4336
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9404 - loss: 0.4448
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9385 - loss: 0.4240
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9248 - loss: 0.4238
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9373 - loss: 0.4030
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9489 - loss: 0.3669
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9297 - loss: 0.3955
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9445 - loss: 0.3451
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9515 - loss: 0.3265
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9363 - loss: 0.3534
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9512 - loss: 0.3330
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9411 - loss: 0.3136
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9485 - loss: 0.2909
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9389 - loss: 0.3153
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9551 - loss: 0.2866
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9563 - loss: 0.2680
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9477 - loss: 0.2794
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9497 - loss: 0.2653
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9559 - loss: 0.2576
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9453 - loss: 0.2603
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9548 - loss: 0.2292
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9445 - loss: 0.2562
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9419 - loss: 0.2505
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9427 - loss: 0.2441
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9455 - loss: 0.2506
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9384 - loss: 0.2378
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9512 - loss: 0.2143
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9457 - loss: 0.2377
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9459 - loss: 0.2107
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9562 - loss: 0.2110
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9518 - loss: 0.2137
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9477 - loss: 0.2217

# %%
import time
import numpy as np
text = "what is the fee"

for i in range(10):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# what is the fee fee
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# what is the fee fee for
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# what is the fee fee for data
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# what is the fee fee for data science
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# what is the fee fee for data science mentorship
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# what is the fee fee for data science mentorship program
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# what is the fee fee for data science mentorship program dsmp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# what is the fee fee for data science mentorship program dsmp 2023
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# what is the fee fee for data science mentorship program dsmp 2023 dsmp
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# what is the fee fee for data science mentorship program dsmp 2023 dsmp 2023

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'you': 2,
#  'i': 3,
#  'to': 4,
#  'a': 5,
#  'have': 6,
#  'is': 7,
#  'of': 8,
#  'will': 9,
#  'can': 10,
#  'what': 11,
#  'course': 12,
#  'program': 13,
#  'for': 14,
#  'in': 15,
#  'on': 16,
#  'be': 17,
#  'and': 18,
#  'if': 19,
#  'all': 20,
#  'sessions': 21,
#  'am': 22,
#  'pay': 23,
#  'payment': 24,
#  'make': 25,
#  'we': 26,
#  'this': 27,
#  'do': 28,
#  'subscription': 29,
#  'where': 30,
#  'rs': 31,
#  'so': 32,
#  'session': 33,
#  'our': 34,
#  'paid': 35,
#  'join': 36,
#  'able': 37,
#  'your': 38,
#  'placement': 39,
#  'fee': 40,
#  'monthly': 41,
#  'not': 42,
#  'get': 43,
#  'yes': 44,
#  'once': 45,
#  'past': 46,
#  'website': 47,
#  'feb': 48,
#  'assistance': 49,
#  'data': 50,
#  '7': 51,
#  '5600': 52,
#  'are': 53,
#  'watch': 54,
#  'mail': 55,
#  'from': 56,
#  'contact': 57,
#  'or': 58,
#  'doubt': 59,
#  'science': 60,
#  'payments': 61,
#  '799': 62,
#  'month': 63,
#  'total': 64,
#  'months': 65,
#  'learning': 66,
#  'case': 67,
#  'part': 68,
#  'by': 69,
#  'late': 70,
#  'dashboard': 71,
#  'task': 72,
#  'don’t': 73,
#  'validity': 74,
#  '15th': 75,
#  'jan': 76,
#  'period': 77,
#  'after': 78,
#  'us': 79,
#  'till': 80,
#  '21st': 81,
#  'that': 82,
#  'about': 83,
#  'mentorship': 84,
#  'follows': 85,
#  'model': 86,
#  'duration': 87,
#  'python': 88,
#  'ml': 89,
#  'studies': 90,
#  'deep': 91,
#  'nlp': 92,
#  'no': 93,
#  'miss': 94,
#  'recording': 95,
#  'even': 96,
#  'class': 97,
#  '2': 98,
#  'how': 99,
#  'absolutely': 100,
#  'middle': 101,
#  'anytime': 102,
#  'see': 103,
#  'submit': 104,
#  'with': 105,
#  'registration': 106,
#  'related': 107,
#  'here': 108,
#  'link': 109,
#  'entire': 110,
#  'suppose': 111,
#  'again': 112,
#  'days': 113,
#  'day': 114,
#  'refund': 115,
#  'living': 116,
#  'outside': 117,
#  'india': 118,
#  'should': 119,
#  'sending': 120,
#  'queries': 121,
#  'videos': 122,
#  'read': 123,
#  'but': 124,
#  'provided': 125,
#  'google': 126,
#  'form': 127,
#  '1': 128,
#  'clearance': 129,
#  'week': 130,
#  'just': 131,
#  'certificate': 132,
#  'earlier': 133,
#  'comes': 134,
#  'under': 135,
#  'guarantee': 136,
#  'dsmp': 137,
#  '2023': 138,
#  'becomes': 139,
#  'approx': 140,
#  'syllabus': 141,
#  'covering': 142,
#  'following': 143,
#  'modules': 144,
#  'fundamentals': 145,
#  'libraries': 146,
#  'analysis': 147,
#  'sql': 148,
#  'maths': 149,
#  'machine': 150,
#  'algorithms': 151,
#  'practical': 152,
#  'mlops': 153,
#  'both': 154,
#  'program’s': 155,
#  'curriculum': 156,
#  'live': 157,
#  'recorded': 158,
#  'go': 159,
#  'back': 160,
#  'find': 161,
#  'schedule': 162,
#  'roughly': 163,
#  'last': 164,
#  'hours': 165,
#  'language': 166,
#  'spoken': 167,
#  'instructor': 168,
#  'during': 169,
#  'hinglish': 170,
#  'informed': 171,
#  'upcoming': 172,
#  'side': 173,
#  'before': 174,
#  'every': 175,
#  'become': 176,
#  'user': 177,
#  'non': 178,
#  'tech': 179,
#  'background': 180,
#  'lectures': 181,
#  'content': 182,
#  'provide': 183,
#  'solutions': 184,
#  'self': 185,
#  'evaluate': 186,
#  'yourself': 187,
#  'questions': 188,
#  'youtube': 189,
#  'channel': 190,
#  'amount': 191,
#  'at': 192,
#  'unfortunately': 193,
#  'then': 194,
#  '1st': 195,
#  '30': 196,
#  'essentially': 197,
#  'wait': 198,
#  'end': 199,
#  'like': 200,
#  'making': 201,
#  'policy': 202,
#  'made': 203,
#  'post': 204,
#  'when': 205,
#  'view': 206,
#  'one': 207,
#  'tricky': 208,
#  'carefully': 209,
#  'valid': 210,
#  'purchased': 211,
#  '20th': 212,
#  'purchase': 213,
#  'over': 214,
#  'installments': 215,
#  'aug': 216,
#  '2024': 217,
#  'why': 218,
#  'lifetime': 219,
#  'because': 220,
#  'low': 221,
#  'reach': 222,
#  'out': 223,
#  'fill': 224,
#  'team': 225,
#  'still': 226,
#  'ask': 227,
#  'doubts': 228,
#  'select': 229,
#  'criteria': 230,
#  'there': 231,
#  'criterias': 232,
#  'attempt': 233,
#  'assessments': 234,
#  'joining': 235,
#  'current': 236,
#  'clarify': 237,
#  'does': 238,
#  'mean': 239,
#  'dont': 240,
#  'any': 241,
#  'jobs': 242,
#  'matter': 243,
#  'interview': 244,
#  'calls': 245,
#  'planning': 246,
#  'placements': 247,
#  'afraid': 248,
#  'disappointed': 249,
#  'portfolio': 250,
#  'building': 251,
#  'soft': 252,
#  'skill': 253,
#  'industry': 254,
#  'mentors': 255,
#  'discussion': 256,
#  'job': 257,
#  'hunting': 258,
#  'strategies': 259}
